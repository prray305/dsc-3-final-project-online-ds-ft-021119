# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Paul Raymond
# * Student pace: Full time
# * Scheduled project review date/time:
# * Instructor name: Brandon Lewis
# * Blog post URL:

# %% [markdown]
# __Import initial libraries and packages__

# %%
#import standard libraries and packages
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
#
import glob

# %%
path = '/Users/paulraymond/Downloads/nyt-comments/Articles'
all_files = glob.glob(path + "/*")

files = []

for filename in all_files:
    df = pd.read_csv(filename, index_col = None, header=0)
    files.append(df)
    
data = pd.concat(files, axis=0, ignore_index=True)
data.head()
# Out:
# /Users/paulraymond/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
#   abstract                 articleID  articleWordCount  \
# 0      NaN  58927e0495d0e0392607e1b3              1129
# 1      NaN  5893033d95d0e0392607e2d6              3082
# 2      NaN  5893039595d0e0392607e2da               693
# 3      NaN  5893109995d0e0392607e2ef              1049
# 4      NaN  5893114495d0e0392607e2f1              1283
#
#                    byline documentType  \
# 0           By KEN BELSON      article
# 1              By UNKNOWN      article
# 2       By MANOHLA DARGIS      article
# 3  By ALEXANDRA S. LEVINE      article
# ...

# %%
#import time libraries / packages
from datetime import datetime, date
from pandas.core import datetools
from pandas import Series
import pandas.tseries
# Out:
# /Users/paulraymond/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#adjust the date format
data['date']= pd.to_datetime(data['pubDate'], format='%Y/%m/%d')
data['pubDate'] = pd.to_datetime(data['pubDate'], format='%Y/%m/%d')
data['pubDate'] = data['pubDate'].dt.date
data.pubDate = pd.to_datetime(data.pubDate)
data.head()
# Out:
#   abstract                 articleID  articleWordCount  \
# 0      NaN  58927e0495d0e0392607e1b3              1129
# 1      NaN  5893033d95d0e0392607e2d6              3082
# 2      NaN  5893039595d0e0392607e2da               693
# 3      NaN  5893109995d0e0392607e2ef              1049
# 4      NaN  5893114495d0e0392607e2f1              1283
#
#                    byline documentType  \
# 0           By KEN BELSON      article
# 1              By UNKNOWN      article
# 2       By MANOHLA DARGIS      article
# 3  By ALEXANDRA S. LEVINE      article
# 4          By BONNIE TSUI      article
#
#                                             headline  \
# 0  N.F.L. vs. Politics Has Been Battle All Season...
# 1                             Voice. Vice. Veracity.
# 2                        A Stand-Up’s Downward Slide
# 3            New York Today: A Groundhog Has Her Day
# 4               A Swimmer’s Communion With the Ocean
#
# ...

# %%
df = data.set_index('date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8339 entries, 2017-02-02 00:26:16 to 2018-05-01 09:00:09
# Data columns (total 16 columns):
# abstract            134 non-null object
# articleID           8339 non-null object
# articleWordCount    8339 non-null int64
# byline              8339 non-null object
# documentType        8339 non-null object
# headline            8339 non-null object
# keywords            8339 non-null object
# multimedia          8339 non-null int64
# newDesk             8339 non-null object
# printPage           8339 non-null int64
# pubDate             8339 non-null datetime64[ns]
# sectionName         8339 non-null object
# snippet             8339 non-null object
# source              8339 non-null object
# typeOfMaterial      8339 non-null object
# webURL              8339 non-null object
# dtypes: datetime64[ns](1), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
dff = df['articleWordCount'].resample('A')

# %%
dff.plot(figsize=(20,16))

# %%
# d_count = data.groupby(['date','newDesk'])['articleID'].count()

# %%
df_articles = df['articleID'].resample('W').count()

# %%
df_articles.plot()

# %%
df['articleCount']=1
df['articleCountWeek']= np.sum(df['articleCount'])
# df['articleCountWeek']
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-17f2a1c60123> in <module>()
# ----> 1 df['articleCount']=1
#       2 df['articleCountWeek']= np.sum(df['articleCount'])
#       3 # df['articleCountWeek']
#       4 df.head(20)
#
# TypeError: 'DataFrameGroupBy' object does not support item assignment

# %%
df_articles_wordcount = df[['articleCountWeek', 'articleWordCount']]
df_articles_wordcount.head(20)
# Out:
#                                                       articleCountWeek  \
# date
# 2017-02-02 00:26:16  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 10:00:24  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 10:01:53  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 10:57:25  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 11:00:03  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 03:00:33  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 08:03:02  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 08:21:23  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 08:21:23  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 08:21:23  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 09:02:47  DatetimeIndexResampler [freq=<Week: weekday=6>...
# 2017-02-02 09:30:02  DatetimeIndexResampler [freq=<Week: weekday=6>...
# ...

# %%
articles_year = df_articles_wordcount.groupby(pd.Grouper(freq='A'))

# %%
articles_year.plot()
# Out:
# date
# 2017-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# Freq: A-DEC, dtype: object

# %%
ax = articles_year.plot('articleWordCount')
# df.plot('Date','B',secondary_y=True, ax=ax)

# %%
d_count.plot()

# %%
d_count_index = d_count.set_index('date')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-274-3b7bca63b86f> in <module>()
# ----> 1 d_count_index = d_count.set_index('date')
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
d_count_index.head()
# Out:
#                date  articleID
# newDesk
# Foreign  2017-01-01          1
# Games    2017-01-01          1
# National 2017-01-01          1
# OpEd     2017-01-01          1
# Culture  2017-01-02          1

# %%
d_count_year = d_count.groupby(pd.Grouper(freq='A'))
# d_count_year = d_count.resample('A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-238-733e1475a815> in <module>()
# ----> 1 d_count_year = d_count.groupby(pd.Grouper(freq='A'))
#       2 # d_count_year = d_count.resample('A')
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
# ...

# %%
d_count_year.plot(subplots=False)
# Out:
# date
# 2017-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2018-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# Freq: A-DEC, Name: date, dtype: object

# %%
#check data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8339 entries, 0 to 8338
# Data columns (total 17 columns):
# abstract            134 non-null object
# articleID           8339 non-null object
# articleWordCount    8339 non-null int64
# byline              8339 non-null object
# documentType        8339 non-null object
# headline            8339 non-null object
# keywords            8339 non-null object
# multimedia          8339 non-null int64
# newDesk             8339 non-null object
# printPage           8339 non-null int64
# pubDate             8339 non-null datetime64[ns]
# sectionName         8339 non-null object
# snippet             8339 non-null object
# source              8339 non-null object
# typeOfMaterial      8339 non-null object
# webURL              8339 non-null object
# date                8339 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
#drop 'pubDate'
data = data.drop(['pubDate'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8339 entries, 0 to 8338
# Data columns (total 16 columns):
# abstract            134 non-null object
# articleID           8339 non-null object
# articleWordCount    8339 non-null int64
# byline              8339 non-null object
# documentType        8339 non-null object
# headline            8339 non-null object
# keywords            8339 non-null object
# multimedia          8339 non-null int64
# newDesk             8339 non-null object
# printPage           8339 non-null int64
# sectionName         8339 non-null object
# snippet             8339 non-null object
# source              8339 non-null object
# typeOfMaterial      8339 non-null object
# webURL              8339 non-null object
# date                8339 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(12)
# memory usage: 1.0+ MB

# %%
data.set_index('date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-c2a3e87596fc> in <module>()
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8339 entries, 2017-02-02 to 2018-05-01
# Data columns (total 15 columns):
# abstract            134 non-null object
# articleID           8339 non-null object
# articleWordCount    8339 non-null int64
# byline              8339 non-null object
# documentType        8339 non-null object
# headline            8339 non-null object
# keywords            8339 non-null object
# multimedia          8339 non-null int64
# newDesk             8339 non-null object
# printPage           8339 non-null int64
# sectionName         8339 non-null object
# snippet             8339 non-null object
# source              8339 non-null object
# typeOfMaterial      8339 non-null object
# webURL              8339 non-null object
# dtypes: int64(3), object(12)
# memory usage: 1.0+ MB

# %%
dataset = data[['date','articleID']].groupby('date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-189-62de826bc68b> in <module>()
# ----> 1 dataset = data[['date','articleID']].groupby('date')
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
# ...

# %%
dataset.head()
# Out:
# date
# 2017-01-01     4
# 2017-01-02     9
# 2017-01-03    30
# 2017-01-04    35
# 2017-01-05    33
# Name: articleID, dtype: int64

# %%
dataset.plot()

# %%
df = data.groupby(pd.Grouper(freq='A'))

# %%
df.plot()
# Out:
# date
# 2017-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# Freq: A-DEC, dtype: object

# %%
#create a new dataframe with date, article count and comment count 
# date = data['date']
articleCount = data.groupby(['date']).count()

# %%
articleCount
# Out:
#             abstract  articleID  articleWordCount  byline  documentType  \
# date
# 2017-01-01         0          4                 4       4             4
# 2017-01-02         0          9                 9       9             9
# 2017-01-03         1         30                30      30            30
# 2017-01-04         2         35                35      35            35
# 2017-01-05         1         33                33      33            33
# 2017-01-06         2         32                32      32            32
# 2017-01-07         1         20                20      20            20
# 2017-01-08         0          5                 5       5             5
# 2017-01-09         1         28                28      28            28
# 2017-01-10         3         35                35      35            35
# 2017-01-11         2         34                34      34            34
# 2017-01-12         3         42                42      42            42
# ...

# %%
#import comments data to calculata # of comments over time
path = '/Users/paulraymond/Downloads/nyt-comments/Comments'
all_files = glob.glob(path + "/*")

files = []

for filename in all_files:
    df = pd.read_csv(filename, index_col = None, header=0)
    files.append(df)
    
comments = pd.concat(files, axis=0, ignore_index=True)
comments.head()
# Out:
# /Users/paulraymond/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/paulraymond/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/paulraymond/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (14,15,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1899975 entries, 0 to 1899974
# Data columns (total 35 columns):
# approveDate              int64
# articleID                object
# articleWordCount         float64
# commentBody              object
# commentID                float64
# commentSequence          float64
# commentTitle             object
# commentType              object
# createDate               float64
# depth                    float64
# editorsSelection         int64
# inReplyTo                float64
# newDesk                  object
# parentID                 float64
# parentUserDisplayName    object
# permID                   object
# picURL                   object
# printPage                float64
# recommendations          float64
# recommendedFlag          float64
# replyCount               float64
# reportAbuseFlag          float64
# sectionName              object
# sharing                  int64
# status                   object
# ...

# %%
comments_articles = comments[['commentID', 'articleID']]

# %%
comments_articles.nunique()
# Out:
# commentID    1850600
# articleID       8466
# dtype: int64

# %%
# df_comments = df.join(comments_articles, on = 'articleID')
df_comments = pd.concat([df, comments_articles], axis=1)

# %%
df_comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1899975 entries, 0 to 1899974
# Data columns (total 36 columns):
# approveDate              float64
# articleID                object
# articleWordCount         float64
# commentBody              object
# commentID                float64
# commentSequence          float64
# commentTitle             object
# commentType              object
# createDate               float64
# depth                    float64
# editorsSelection         float64
# inReplyTo                float64
# newDesk                  object
# parentID                 float64
# parentUserDisplayName    object
# permID                   object
# picURL                   object
# printPage                float64
# recommendations          float64
# recommendedFlag          float64
# replyCount               float64
# reportAbuseFlag          float64
# sectionName              object
# sharing                  float64
# status                   object
# ...
